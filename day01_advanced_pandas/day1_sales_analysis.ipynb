# %% [markdown]
# # Day 1 - Advanced Pandas Operations
#
# Focus:
# - Advanced filtering
# - Multi-index
# - GroupBy deep dives
# - Pivot / Pivot tables
# - Apply vs Vectorization
#
# Mini Challenge:
# Messy Sales Dataset Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print ("Environment is set up and ready to go!")
# Out:
# Environment is set up and ready to go!

# %%
df = pd.read_csv("../data/SuperStoreOrders.csv")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_id        51290 non-null  str
#  1   order_date      51290 non-null  str
#  2   ship_date       51290 non-null  str
#  3   ship_mode       51290 non-null  str
#  4   customer_name   51290 non-null  str
#  5   segment         51290 non-null  str
#  6   state           51290 non-null  str
#  7   country         51290 non-null  str
#  8   market          51290 non-null  str
#  9   region          51290 non-null  str
#  10  product_id      51290 non-null  str
#  11  category        51290 non-null  str
#  12  sub_category    51290 non-null  str
#  13  product_name    51290 non-null  str
#  14  sales           51290 non-null  str
#  15  quantity        51290 non-null  int64
#  16  discount        51290 non-null  float64
#  17  profit          51290 non-null  float64
# ...

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  6/1/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  8/1/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  5/1/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  5/1/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  8/1/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#           category sub_category                 product_name sales quantity  \
# ...

# %%
df.shape
# Out:
# (51290, 21)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_id        51290 non-null  str
#  1   order_date      51290 non-null  str
#  2   ship_date       51290 non-null  str
#  3   ship_mode       51290 non-null  str
#  4   customer_name   51290 non-null  str
#  5   segment         51290 non-null  str
#  6   state           51290 non-null  str
#  7   country         51290 non-null  str
#  8   market          51290 non-null  str
#  9   region          51290 non-null  str
#  10  product_id      51290 non-null  str
#  11  category        51290 non-null  str
#  12  sub_category    51290 non-null  str
#  13  product_name    51290 non-null  str
#  14  sales           51290 non-null  str
#  15  quantity        51290 non-null  int64
#  16  discount        51290 non-null  float64
#  17  profit          51290 non-null  float64
# ...

# %%
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  6/1/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  8/1/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  5/1/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  5/1/2011    Second Class
# 4        IN-2011-47883    1/1/2011  8/1/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  31-12-2014  4/1/2015  Standard Class
# 51286     MO-2014-2560  31-12-2014  5/1/2015  Standard Class
# 51287   MX-2014-110527  31-12-2014  2/1/2015    Second Class
# 51288   MX-2014-114783  31-12-2014  6/1/2015  Standard Class
# 51289   CA-2014-156720  31-12-2014  4/1/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_id        51290 non-null  str
#  1   order_date      51290 non-null  str
#  2   ship_date       51290 non-null  str
#  3   ship_mode       51290 non-null  str
#  4   customer_name   51290 non-null  str
#  5   segment         51290 non-null  str
#  6   state           51290 non-null  str
#  7   country         51290 non-null  str
#  8   market          51290 non-null  str
#  9   region          51290 non-null  str
#  10  product_id      51290 non-null  str
#  11  category        51290 non-null  str
#  12  sub_category    51290 non-null  str
#  13  product_name    51290 non-null  str
#  14  sales           51290 non-null  str
#  15  quantity        51290 non-null  int64
#  16  discount        51290 non-null  float64
#  17  profit          51290 non-null  float64
# ...

# %%
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  6/1/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  8/1/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  5/1/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  5/1/2011    Second Class
# 4        IN-2011-47883    1/1/2011  8/1/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  31-12-2014  4/1/2015  Standard Class
# 51286     MO-2014-2560  31-12-2014  5/1/2015  Standard Class
# 51287   MX-2014-110527  31-12-2014  2/1/2015    Second Class
# 51288   MX-2014-114783  31-12-2014  6/1/2015  Standard Class
# 51289   CA-2014-156720  31-12-2014  4/1/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df[['sales']]
# Out:
#       sales
# 0       408
# 1       120
# 2        66
# 3        45
# 4       114
# ...     ...
# 51285    14
# 51286     4
# 51287    26
# 51288     7
# 51289     3
#
# [51290 rows x 1 columns]

# %%
df.describe()
# Out:
#            quantity      discount        profit  shipping_cost          year
# count  51290.000000  51290.000000  51290.000000   51290.000000  51290.000000
# mean       3.476545      0.142908     28.641740      26.375915   2012.777208
# std        2.278766      0.212280    174.424113      57.296804      1.098931
# min        1.000000      0.000000  -6599.978000       0.000000   2011.000000
# 25%        2.000000      0.000000      0.000000       2.610000   2012.000000
# 50%        3.000000      0.000000      9.240000       7.790000   2013.000000
# 75%        5.000000      0.200000     36.810000      24.450000   2014.000000
# max       14.000000      0.850000   8399.976000     933.570000   2014.000000

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_id        51290 non-null  str
#  1   order_date      51290 non-null  str
#  2   ship_date       51290 non-null  str
#  3   ship_mode       51290 non-null  str
#  4   customer_name   51290 non-null  str
#  5   segment         51290 non-null  str
#  6   state           51290 non-null  str
#  7   country         51290 non-null  str
#  8   market          51290 non-null  str
#  9   region          51290 non-null  str
#  10  product_id      51290 non-null  str
#  11  category        51290 non-null  str
#  12  sub_category    51290 non-null  str
#  13  product_name    51290 non-null  str
#  14  sales           51290 non-null  str
#  15  quantity        51290 non-null  int64
#  16  discount        51290 non-null  float64
#  17  profit          51290 non-null  float64
# ...

# %%
df[['order_id', 'order_date', 'customer_name']]
# Out:
#               order_id  order_date     customer_name
# 0         AG-2011-2040    1/1/2011   Toby Braunhardt
# 1        IN-2011-47883    1/1/2011       Joseph Holt
# 2         HU-2011-1220    1/1/2011     Annie Thurman
# 3      IT-2011-3647632    1/1/2011      Eugene Moren
# 4        IN-2011-47883    1/1/2011       Joseph Holt
# ...                ...         ...               ...
# 51285   CA-2014-115427  31-12-2014        Erica Bern
# 51286     MO-2014-2560  31-12-2014         Liz Preis
# 51287   MX-2014-110527  31-12-2014  Charlotte Melton
# 51288   MX-2014-114783  31-12-2014     Tamara Dahlen
# 51289   CA-2014-156720  31-12-2014     Jill Matthias
#
# [51290 rows x 3 columns]

# %%
df.shae
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df.shae
#
# File d:\advanced-data-wrangling-lab\venv\Lib\site-packages\pandas\core\generic.py:6206, in NDFrame.__getattr__(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'shae'

# %%
df.shape
# Out:
# (51290, 21)

# %%
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  6/1/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  8/1/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  5/1/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  5/1/2011    Second Class
# 4        IN-2011-47883    1/1/2011  8/1/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  31-12-2014  4/1/2015  Standard Class
# 51286     MO-2014-2560  31-12-2014  5/1/2015  Standard Class
# 51287   MX-2014-110527  31-12-2014  2/1/2015    Second Class
# 51288   MX-2014-114783  31-12-2014  6/1/2015  Standard Class
# 51289   CA-2014-156720  31-12-2014  4/1/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df['sales'].max()
# Out:
# '999'

# %%
df['sales'].min()
# Out:
# '0'

# %%
df['sales'].dtypes
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %%
df['sales'] = pd.to_numeric(df['sales'], errors = 'coerce')

# %%
df['sales'].dtypes
# Out:
# dtype('float64')

# %%
df['sales'].mean()
# Out:
# np.float64(161.01783806000822)

# %%
df['sales'].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 df['sales'].mean()
#
# File d:\advanced-data-wrangling-lab\venv\Lib\site-packages\pandas\util\_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File d:\advanced-data-wrangling-lab\venv\Lib\site-packages\pandas\core\series.py:8113, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    8063 @deprecate_nonkeyword_arguments(Pandas4Warning, allowed_args=["self"], name="mean")
#    8064 def mean(
#    8065     self,
#    (...)   8069     **kwargs,
#    8070 ) -> Any:
# ...

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [order_id, order_date, ship_date, ship_mode, customer_name, segment, state, country, market, region, product_id, category, sub_category, product_name, sales, quantity, discount, profit, shipping_cost, order_priority, year]
# Index: []
#
# [0 rows x 21 columns]

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  6/1/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  8/1/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  5/1/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  5/1/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  8/1/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#           category sub_category                 product_name sales quantity  \
# ...

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='str')

# %%
df.dtypes
# Out:
# order_id              str
# order_date            str
# ship_date             str
# ship_mode             str
# customer_name         str
# segment               str
# state                 str
# country               str
# market                str
# region                str
# product_id            str
# category              str
# sub_category          str
# product_name          str
# sales                 str
# quantity            int64
# discount          float64
# profit            float64
# shipping_cost     float64
# order_priority        str
# year                int64
# dtype: object

# %%
high_sales = df[df['sales']>1000]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 high_sales = df[df['sales']>1000]
#
# File d:\advanced-data-wrangling-lab\venv\Lib\site-packages\pandas\core\ops\common.py:85, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      82     other = sanitize_array(other, None)
#      83     other = ensure_wrapped_if_datetimelike(other)
# ---> 85 return method(self, other)
#
# File d:\advanced-data-wrangling-lab\venv\Lib\site-packages\pandas\core\arraylike.py:58, in OpsMixin.__gt__(self, other)
#      56 @unpack_zerodim_and_defer("__gt__")
#      57 def __gt__(self, other):
# ---> 58     return self._cmp_method(other, operator.gt)
#
# File d:\advanced-data-wrangling-lab\venv\Lib\site-packages\pandas\core\series.py:6735, in Series._cmp_method(self, other, op)
#    6732 lvalues = self._values
# ...

# %%
df['sales'] = pd.to_numeric(df['sales'], errors = 'coerce')

# %%
high_sales = df[df['sales']>1000]

# %%
df.dtypes
# Out:
# order_id              str
# order_date            str
# ship_date             str
# ship_mode             str
# customer_name         str
# segment               str
# state                 str
# country               str
# market                str
# region                str
# product_id            str
# category              str
# sub_category          str
# product_name          str
# sales                 str
# quantity            int64
# discount          float64
# profit            float64
# shipping_cost     float64
# order_priority        str
# year                int64
# sale              float64
# dtype: object

# %%
high_sales.head()
# Out:
# Empty DataFrame
# Columns: [order_id, order_date, ship_date, ship_mode, customer_name, segment, state, country, market, region, product_id, category, sub_category, product_name, sales, quantity, discount, profit, shipping_cost, order_priority, year, sale]
# Index: []
#
# [0 rows x 22 columns]

# %%
high_sales
# Out:
# Empty DataFrame
# Columns: [order_id, order_date, ship_date, ship_mode, customer_name, segment, state, country, market, region, product_id, category, sub_category, product_name, sales, quantity, discount, profit, shipping_cost, order_priority, year, sale]
# Index: []
#
# [0 rows x 22 columns]

# %%
df['sales'].max()
# Out:
# np.float64(999.0)

# %%
df['sales'].describe()
# Out:
# count    48660.000000
# mean       161.017838
# std        201.092519
# min          0.000000
# 25%         29.000000
# 50%         77.000000
# 75%        208.000000
# max        999.000000
# Name: sales, dtype: float64

# %%
high_sales = df[df['sale']>500]

# %%
high_sales
# Out:
#               order_id  order_date  ship_date       ship_mode  \
# 8        ID-2011-80230    3/1/2011   9/1/2011  Standard Class
# 9         IZ-2011-4680    3/1/2011   7/1/2011  Standard Class
# 12     ES-2011-4869686    3/1/2011   7/1/2011  Standard Class
# 59      CA-2011-167199    7/1/2011  11/1/2011  Standard Class
# 64     ES-2011-5433855    7/1/2011   8/1/2011     First Class
# ...                ...         ...        ...             ...
# 51230     RS-2014-1460  31-12-2014   2/1/2015    Second Class
# 51232  ES-2014-3458802  31-12-2014   5/1/2015  Standard Class
# 51234  ES-2014-1695428  31-12-2014   2/1/2015    Second Class
# 51236  ES-2014-5281275  31-12-2014   4/1/2015    Second Class
# 51239    ID-2014-54442  31-12-2014   4/1/2015  Standard Class
#
#            customer_name      segment                       state  \
# 8           Ken Lonsdale     Consumer                    Auckland
# 9       Lindsay Williams    Corporate                      Ninawa
# ...

# %%
high_sales.shape
# Out:
# (4112, 22)

# %%
high_sales_consumer = df[(df['sales']>500) & (df['segment'] == 'Consumer')]

# %%
high_sales_consumer
# Out:
#               order_id  order_date   ship_date       ship_mode  \
# 8        ID-2011-80230    3/1/2011    9/1/2011  Standard Class
# 12     ES-2011-4869686    3/1/2011    7/1/2011  Standard Class
# 85     IT-2011-4546695    8/1/2011  14-01-2011  Standard Class
# 128      IN-2011-39308   11/1/2011  18-01-2011  Standard Class
# 162       EG-2011-4270  13-01-2011  18-01-2011  Standard Class
# ...                ...         ...         ...             ...
# 51052     EG-2014-8040  29-12-2014    2/1/2015  Standard Class
# 51057    ID-2014-48828  29-12-2014    2/1/2015  Standard Class
# 51162  ES-2014-5329048  30-12-2014    4/1/2015  Standard Class
# 51230     RS-2014-1460  31-12-2014    2/1/2015    Second Class
# 51234  ES-2014-1695428  31-12-2014    2/1/2015    Second Class
#
#             customer_name   segment           state         country  market  \
# 8            Ken Lonsdale  Consumer        Auckland     New Zealand    APAC
# ...

# %%
tech_sales = df.query("sales > 500 and category == 'Technology'")

# %%
tech_sales
# Out:
#               order_id  order_date   ship_date       ship_mode  \
# 8        ID-2011-80230    3/1/2011    9/1/2011  Standard Class
# 67      CA-2011-167199    7/1/2011   11/1/2011  Standard Class
# 102       HU-2011-1380   10/1/2011   10/1/2011        Same Day
# 128      IN-2011-39308   11/1/2011  18-01-2011  Standard Class
# 129      IN-2011-79761   11/1/2011  16-01-2011  Standard Class
# ...                ...         ...         ...             ...
# 51057    ID-2014-48828  29-12-2014    2/1/2015  Standard Class
# 51230     RS-2014-1460  31-12-2014    2/1/2015    Second Class
# 51232  ES-2014-3458802  31-12-2014    5/1/2015  Standard Class
# 51236  ES-2014-5281275  31-12-2014    4/1/2015    Second Class
# 51239    ID-2014-54442  31-12-2014    4/1/2015  Standard Class
#
#            customer_name      segment             state         country  \
# 8           Ken Lonsdale     Consumer          Auckland     New Zealand
# ...

# %%
df.groupby('category')['sales'].sum()
# Out:
# category
# Furniture          2406605.0
# Office Supplies    2790258.0
# Technology         2638265.0
# Name: sales, dtype: float64

# %%
df.groupby("category")["sales"].sum().sort_values(ascending=False)
# Out:
# category
# Office Supplies    2790258.0
# Technology         2638265.0
# Furniture          2406605.0
# Name: sales, dtype: float64

# %%
df.groupby("category").agg({
    "sales": ["sum", "mean"],
    "profit": ["sum", "mean"]
})
# Out:
#                      sales                    profit
#                        sum        mean           sum       mean
# category
# Furniture        2406605.0  270.222883  286782.25380  29.038300
# Office Supplies  2790258.0   90.781429  518473.83430  16.578961
# Technology       2638265.0  292.555445  663778.73318  65.454958

# %%
df.groupby(["category", "segment"])["sales"].sum()
# Out:
# category         segment
# Furniture        Consumer       1226880.0
#                  Corporate       755916.0
#                  Home Office     423809.0
# Office Supplies  Consumer       1454836.0
#                  Corporate       823404.0
#                  Home Office     512018.0
# Technology       Consumer       1376402.0
#                  Corporate       789941.0
#                  Home Office     471922.0
# Name: sales, dtype: float64

# %%
multi_sales = df.groupby(
    ["category", "segment"]
)["sales"].sum()

multi_sales
# Out:
# category         segment
# Furniture        Consumer       1226880.0
#                  Corporate       755916.0
#                  Home Office     423809.0
# Office Supplies  Consumer       1454836.0
#                  Corporate       823404.0
#                  Home Office     512018.0
# Technology       Consumer       1376402.0
#                  Corporate       789941.0
#                  Home Office     471922.0
# Name: sales, dtype: float64

# %%
pd.pivot_table(
    df,
    values="sales",
    index="category",
    aggfunc="sum"
)
# Out:
#                      sales
# category
# Furniture        2406605.0
# Office Supplies  2790258.0
# Technology       2638265.0

# %%
pd.pivot_table(
    df,
    values="sales",
    index="category",
    columns="segment",
    aggfunc="sum"
)
# Out:
# segment           Consumer  Corporate  Home Office
# category
# Furniture        1226880.0   755916.0     423809.0
# Office Supplies  1454836.0   823404.0     512018.0
# Technology       1376402.0   789941.0     471922.0

# %%
df["profit_status"] = np.where(
    df["profit"] > 0,
    "Profit",
    "Loss"
)

df[["profit", "profit_status"]].head()
# Out:
#     profit profit_status
# 0  106.140        Profit
# 1   36.036        Profit
# 2   29.640        Profit
# 3  -26.055          Loss
# 4   37.770        Profit
