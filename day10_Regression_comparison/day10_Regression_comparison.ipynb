# %%
import pandas as pd

results = pd.DataFrame({
    'Model': [
        'Ridge Regression',
        'Linear Regression',
        'Gradient Boosting Regressor',
        'XGBoost Regressor',
        'Random Forest Regressor',
        'Decision Tree Regressor',
        'Lasso Regression'
    ],

    'R2 Score': [
        0.9127,
        0.9103,
        0.9072,
        0.9047,
        0.8867,
        0.7752,
        0.6895
    ],

    'MAE': [
        0.0911,
        0.0899,
        0.0919,
        0.0923,
        0.0995,
        0.1478,
        0.1711
    ],

    'MSE': [
        0.0163,
        0.0167,
        0.0173,
        0.0178,
        0.0212,
        0.0419,
        0.0579
    ],

    'RMSE': [
        0.1277,
        0.1294,
        0.1316,
        0.1333,
        0.1454,
        0.2048,
        0.2407
    ]
})

results
# Out:
#                          Model  R2 Score     MAE     MSE    RMSE
# 0             Ridge Regression    0.9127  0.0911  0.0163  0.1277
# 1            Linear Regression    0.9103  0.0899  0.0167  0.1294
# 2  Gradient Boosting Regressor    0.9072  0.0919  0.0173  0.1316
# 3            XGBoost Regressor    0.9047  0.0923  0.0178  0.1333
# 4      Random Forest Regressor    0.8867  0.0995  0.0212  0.1454
# 5      Decision Tree Regressor    0.7752  0.1478  0.0419  0.2048
# 6             Lasso Regression    0.6895  0.1711  0.0579  0.2407
