# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('../data/train.csv')

df.head(5)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
df.isnull().sum().sort_values(ascending=False).head(20)
# Out:
# PoolQC          1453
# MiscFeature     1406
# Alley           1369
# Fence           1179
# MasVnrType       872
# FireplaceQu      690
# LotFrontage      259
# GarageQual        81
# GarageFinish      81
# GarageType        81
# GarageYrBlt       81
# GarageCond        81
# BsmtFinType2      38
# BsmtExposure      38
# BsmtCond          37
# BsmtQual          37
# BsmtFinType1      37
# MasVnrArea         8
# Electrical         1
# Condition2         0
# dtype: int64

# %%
missing_pct = (df.isnull().sum()/len(df)*100).sort_values(ascending=False)

sns.barplot(
    x=missing_pct.head(20).values,
    y=missing_pct.head(20).index
)
plt.xlabel("Missing %")
plt.title("Top 20 Missing Percentage")
plt.show()

# %%
df.isnull().sum().sort_values(ascending=False).head(4)
# Out:
# PoolQC         1453
# MiscFeature    1406
# Alley          1369
# Fence          1179
# dtype: int64

# %%
drop_cols = [
    'PoolQC', 'MiscFeature','Alley','Fence'   
]

df = df.drop(drop_cols, axis=1)

# %%
df.isnull().sum().sort_values(ascending=False).head(4)
# Out:
# MasVnrType      872
# FireplaceQu     690
# LotFrontage     259
# GarageFinish     81
# dtype: int64

# %%
df['MasVnrType'].head(20)
# Out:
# 0     BrkFace
# 1         NaN
# 2     BrkFace
# 3         NaN
# 4     BrkFace
# 5         NaN
# 6       Stone
# 7       Stone
# 8         NaN
# 9         NaN
# 10        NaN
# 11      Stone
# 12        NaN
# 13      Stone
# 14    BrkFace
# 15        NaN
# 16    BrkFace
# 17        NaN
# 18        NaN
# 19        NaN
# Name: MasVnrType, dtype: str

# %%
df['MasVnrType'] = df['MasVnrType'].fillna("No_MasVnr")

# %%
df.isnull().sum().sort_values(ascending=False).head(4)
# Out:
# FireplaceQu     690
# LotFrontage     259
# GarageFinish     81
# GarageYrBlt      81
# dtype: int64

# %%
df['FireplaceQu'] = df['FireplaceQu'].fillna("N0_firePlace")

# %%
df['LotFrontage'].head(20)
# Out:
# 0     65.0
# 1     80.0
# 2     68.0
# 3     60.0
# 4     84.0
# 5     85.0
# 6     75.0
# 7      NaN
# 8     51.0
# 9     50.0
# 10    70.0
# 11    85.0
# 12     NaN
# 13    91.0
# 14     NaN
# 15    51.0
# 16     NaN
# 17    72.0
# 18    66.0
# 19    70.0
# Name: LotFrontage, dtype: float64

# %%
df['LotFrontage_missing'] = df['LotFrontage'].isnull().astype(int)

# %%
df['LotFrontage'] = df['LotFrontage'].fillna(df['LotFrontage'].median())

# %%
df.isnull().sum().sort_values(ascending=False).head(6)
# Out:
# GarageType      81
# GarageYrBlt     81
# GarageCond      81
# GarageFinish    81
# GarageQual      81
# BsmtFinType2    38
# dtype: int64

# %%
garage_cols = ['GarageType','GarageCond','GarageFinish', 'GarageQual']

# %%
for col in garage_cols:
    df[col] = df[col].fillna("No_garage")

# %%
df.isnull().sum().sort_values(ascending=False).head(6)
# Out:
# GarageYrBlt     81
# BsmtFinType2    38
# BsmtExposure    38
# BsmtQual        37
# BsmtFinType1    37
# BsmtCond        37
# dtype: int64

# %%
df['GarageYrBlt'] = df['GarageYrBlt'].fillna(df['GarageYrBlt'].median())

# %%
df.isnull().sum().sort_values(ascending=False).head(6)
# Out:
# BsmtExposure    38
# BsmtFinType2    38
# BsmtFinType1    37
# BsmtQual        37
# BsmtCond        37
# MasVnrArea       8
# dtype: int64

# %%
col_bsmt = [
    'BsmtExposure','BsmtFinType2','BsmtFinType1','BsmtQual','BsmtCond'
]

# %%
for col in col_bsmt:
    df[col] = df[col].fillna('No_Bsmt')

# %%
df.isnull().sum().sort_values(ascending=False).head(6)
# Out:
# MasVnrArea     8
# Electrical     1
# MSZoning       0
# LotFrontage    0
# Id             0
# MSSubClass     0
# dtype: int64

# %%
df['MasVnrArea'] = df['MasVnrArea'].fillna(df['MasVnrArea'].median())

# %%
df.isnull().sum().sort_values(ascending=False).head(6)
# Out:
# Electrical     1
# Id             0
# MSZoning       0
# LotFrontage    0
# LotArea        0
# MSSubClass     0
# dtype: int64

# %%
df['Electrical'] = df['Electrical'].fillna(df['Electrical'].mode()[0])

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Id                     0
# MSSubClass             0
# MSZoning               0
# LotFrontage            0
# LotArea                0
#                       ..
# YrSold                 0
# SaleType               0
# SaleCondition          0
# SalePrice              0
# LotFrontage_missing    0
# Length: 78, dtype: int64

# %% [markdown]
# Now we do not have any null values. we will check for any duplicate values

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# No Duplilcate values as  well.

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 78 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   1460 non-null   int64
#  1   MSSubClass           1460 non-null   int64
#  2   MSZoning             1460 non-null   str
#  3   LotFrontage          1460 non-null   float64
#  4   LotArea              1460 non-null   int64
#  5   Street               1460 non-null   str
#  6   LotShape             1460 non-null   str
#  7   LandContour          1460 non-null   str
#  8   Utilities            1460 non-null   str
#  9   LotConfig            1460 non-null   str
#  10  LandSlope            1460 non-null   str
#  11  Neighborhood         1460 non-null   str
#  12  Condition1           1460 non-null   str
#  13  Condition2           1460 non-null   str
#  14  BldgType             1460 non-null   str
#  15  HouseStyle           1460 non-null   str
#  16  OverallQual          1460 non-null   int64
#  17  OverallCond          1460 non-null   int64
#  18  YearBuilt            1460 non-null   int64
#  19  YearRemodAdd         1460 non-null   int64
#  20  RoofStyle            1460 non-null   str
#  21  RoofMatl             1460 non-null   str
#  22  Exterior1st          1460 non-null   str
#  23  Exterior2nd          1460 non-null   str
#  24  MasVnrType           1460 non-null   str
#  25  MasVnrArea           1460 non-null   float64
#  26  ExterQual            1460 non-null   str
#  27  ExterCond            1460 non-null   str
#  28  Foundation           1460 non-null   str
#  29  BsmtQual             1460 non-null   str
#  30  BsmtCond             1460 non-null   str
#  31  BsmtExposure         1460 non-null   str
#  32  BsmtFinType1         1460 non-null   str
#  33  BsmtFinSF1           1460 non-null   int64
#  34  BsmtFinType2         1460 non-null   str
#  35  BsmtFinSF2           1460 non-null   int64
#  36  BsmtUnfSF            1460 non-null   int64
#  37  TotalBsmtSF          1460 non-null   int64
#  38  Heating              1460 non-null   str
#  39  HeatingQC            1460 non-null   str
#  40  CentralAir           1460 non-null   str
#  41  Electrical           1460 non-null   str
#  42  1stFlrSF             1460 non-null   int64
#  43  2ndFlrSF             1460 non-null   int64
#  44  LowQualFinSF         1460 non-null   int64
#  45  GrLivArea            1460 non-null   int64
#  46  BsmtFullBath         1460 non-null   int64
#  47  BsmtHalfBath         1460 non-null   int64
#  48  FullBath             1460 non-null   int64
#  49  HalfBath             1460 non-null   int64
#  50  BedroomAbvGr         1460 non-null   int64
#  51  KitchenAbvGr         1460 non-null   int64
#  52  KitchenQual          1460 non-null   str
#  53  TotRmsAbvGrd         1460 non-null   int64
#  54  Functional           1460 non-null   str
#  55  Fireplaces           1460 non-null   int64
#  56  FireplaceQu          1460 non-null   str
#  57  GarageType           1460 non-null   str
#  58  GarageYrBlt          1460 non-null   float64
#  59  GarageFinish         1460 non-null   str
#  60  GarageCars           1460 non-null   int64
#  61  GarageArea           1460 non-null   int64
#  62  GarageQual           1460 non-null   str
#  63  GarageCond           1460 non-null   str
#  64  PavedDrive           1460 non-null   str
#  65  WoodDeckSF           1460 non-null   int64
#  66  OpenPorchSF          1460 non-null   int64
#  67  EnclosedPorch        1460 non-null   int64
#  68  3SsnPorch            1460 non-null   int64
#  69  ScreenPorch          1460 non-null   int64
#  70  PoolArea             1460 non-null   int64
#  71  MiscVal              1460 non-null   int64
#  72  MoSold               1460 non-null   int64
#  73  YrSold               1460 non-null   int64
#  74  SaleType             1460 non-null   str
#  75  SaleCondition        1460 non-null   str
#  76  SalePrice            1460 non-null   int64
#  77  LotFrontage_missing  1460 non-null   int64
# dtypes: float64(3), int64(36), str(39)
# memory usage: 889.8 KB

# %% [markdown]
# All Dytpes are also correct

# %%
df.head(3)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0   1          60       RL         65.0     8450   Pave      Reg         Lvl
# 1   2          20       RL         80.0     9600   Pave      Reg         Lvl
# 2   3          60       RL         68.0    11250   Pave      IR1         Lvl
#
#   Utilities LotConfig  ... 3SsnPorch ScreenPorch PoolArea MiscVal MoSold  \
# 0    AllPub    Inside  ...         0           0        0       0      2
# 1    AllPub       FR2  ...         0           0        0       0      5
# 2    AllPub    Inside  ...         0           0        0       0      9
#
#   YrSold  SaleType  SaleCondition  SalePrice  LotFrontage_missing
# 0   2008        WD         Normal     208500                    0
# 1   2007        WD         Normal     181500                    0
# 2   2008        WD         Normal     223500                    0
#
# [3 rows x 78 columns]

# %%
sns.histplot(df['SalePrice'])
# Out:
# <Axes: xlabel='SalePrice', ylabel='Count'>

# %% [markdown]
# now before making the Train and testing sets we need to normalize the value for the SalePrice as it is in very high number so we are going to use the transformation featuring for it.

# %%
df['Log_SalePrice'] = np.log1p(df['SalePrice'])

# %%
sns.histplot(df['Log_SalePrice'])
# Out:
# <Axes: xlabel='Log_SalePrice', ylabel='Count'>

# %% [markdown]
# this is dataset is fulling cleaned and featured

# %%
print('Shape of tables: ', df.shape)
print('Null Values: ',df.isnull().sum().sum())
print('Duplicated Values: ',df.duplicated().sum())
# Out:
# Shape of tables:  (1460, 79)
# Null Values:  0
# Duplicated Values:  0

# %% [markdown]
# now we will be spliting the features and target

# %%
df.head(1)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0   1          60       RL         65.0     8450   Pave      Reg         Lvl
#
#   Utilities LotConfig  ... ScreenPorch PoolArea MiscVal MoSold YrSold  \
# 0    AllPub    Inside  ...           0        0       0      2   2008
#
#   SaleType  SaleCondition  SalePrice  LotFrontage_missing  Log_SalePrice
# 0       WD         Normal     208500                    0      12.247699
#
# [1 rows x 79 columns]

# %%
X = df.drop(df[['SalePrice','Log_SalePrice']], axis=1)

y = df['Log_SalePrice']

# %%
numeric_feature = X.select_dtypes(
    include = ['int64', 'float64']
).columns

categorical_features = X.select_dtypes(
    include = ['str']
).columns

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

# %%
numeric_pp = Pipeline([
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])

catergorical_pp = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('encoder', OneHotEncoder(handle_unknown='ignore'))
])

# %%
prepro = ColumnTransformer([
    ('num', numeric_pp, numeric_feature),
    ('cat', catergorical_pp, categorical_features)
])

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
GBR_pp = Pipeline([
    ('preprocessor',  prepro),
    ('model', GradientBoostingRegressor(
        random_state=42,
        n_estimators=100,
        learning_rate=0.1
    ))
])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test, y_train, y_test = train_test_split(
    X,y,test_size=.20, random_state=42
)

# %%
GBR_pp.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   Index(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrS...
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'SaleType', 'SaleCondition'],
#       dtype='str'))])),
#                 ('model', GradientBoostingRegressor(random_state=42))])

# %%
GBR_pred = GBR_pp.predict(X_test)

# %%
from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    root_mean_squared_error,
    r2_score
)

print('R2 score: ', r2_score(y_test, GBR_pred))
print('MAE: ', mean_absolute_error(y_test, GBR_pred))
print('MSE: ', mean_squared_error(y_test,GBR_pred))
print('RMSE: ', root_mean_squared_error(y_test, GBR_pred))
# Out:
# R2 score:  0.9072187290311338
# MAE:  0.09189013930559985
# MSE:  0.017314004698046906
# RMSE:  0.13158269148351887

# %%
GBR_steps = GBR_pp.named_steps['model']

# %%
importance = GBR_steps.feature_importances_

# %%
feature_names = GBR_pp.named_steps['preprocessor'].get_feature_names_out()

# %%
importantfeature = pd.DataFrame({
    'Featurenames': feature_names,
    'featureimportance': importance
})

# %%
top10 = importantfeature.head(10).sort_values('featureimportance', ascending=False)

top10.head()
# Out:
#         Featurenames  featureimportance
# 4   num__OverallQual           0.430457
# 6     num__YearBuilt           0.047587
# 7  num__YearRemodAdd           0.028036
# 9    num__BsmtFinSF1           0.024727
# 3       num__LotArea           0.022447

# %%
plt.figure(figsize=(8,6))
plt.barh(top10['Featurenames'], top10['featureimportance'])
plt.title('Top 10 features')
plt.xlabel('Importance')
plt.ylabel('Features')
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# Now we will be doing the  permutation

# %%
from sklearn.inspection import permutation_importance

# %%
perm_importance = permutation_importance(
    GBR_pp,
    X_test,
    y_test,
    n_repeats=10,
    scoring='r2',
    random_state=42
)

# %%
permdf= pd.DataFrame({
    'pfeaturenames': X_test.columns,
    'pfeatureimportance': perm_importance.importances_mean
})

# %%
ptop10 = permdf.head(10).sort_values(by="pfeatureimportance", ascending=False)

ptop10.head(10)
# Out:
#   pfeaturenames  pfeatureimportance
# 4       LotArea            0.011190
# 2      MSZoning            0.005484
# 9     LotConfig            0.000379
# 1    MSSubClass            0.000356
# 7   LandContour            0.000285
# 0            Id            0.000252
# 6      LotShape            0.000199
# 3   LotFrontage            0.000168
# 5        Street            0.000000
# 8     Utilities            0.000000

# %%
plt.figure(figsize=(8,6))
plt.barh(ptop10['pfeaturenames'], ptop10['pfeatureimportance'])
plt.title("Top 10 features after permutation")
plt.xlabel('Importance')
plt.ylabel('features')
plt.gca().invert_yaxis()
plt.show()
